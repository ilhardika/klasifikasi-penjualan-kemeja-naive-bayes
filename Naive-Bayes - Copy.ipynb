# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.naive_bayes import GaussianNB

# %% [markdown]
# # Data

# %%
df = pd.read_csv('data_kemeja.csv', sep=';')
df
# Out:
#             bahan warna_kemeja       tipe_kerah     tipe_lengan  motif  \
# 0    Katun Oxford        Hijau  Straight Collar  Lengan Panjang  Polos
# 1    Katun Oxford         Army  Straight Collar  Lengan Panjang  Polos
# 2    Katun Oxford  Coklat Muda  Straight Collar   Lengan Pendek  Polos
# 3    Katun Oxford       Coklat  Straight Collar  Lengan Panjang  Polos
# 4    Katun Oxford        Khaki  Straight Collar  Lengan Panjang  Polos
# ..            ...          ...              ...             ...    ...
# 398         Katun       Coklat  Straight Collar  Lengan Panjang  Batik
# 399         Katun         Navy  Straight Collar  Lengan Panjang  Batik
# 400         Katun       Coklat  Straight Collar  Lengan Panjang  Batik
# 401         Katun        Putih  Straight Collar  Lengan Panjang  Batik
# 402         Katun         Biru  Straight Collar  Lengan Panjang  Batik
#
#     posisi_motif   warna_motif   harga penjualan
# 0      Tidak Ada     Tidak Ada  149000    Rendah
# 1      Tidak Ada     Tidak Ada  149000    Rendah
# 2      Tidak Ada     Tidak Ada  129000    Rendah
# 3      Tidak Ada     Tidak Ada  149000    Tinggi
# 4      Tidak Ada     Tidak Ada  149000    Rendah
# ..           ...           ...     ...       ...
# 398   Area Bawah   Krem Coklat  169000    Rendah
# 399    Area Atas   Krem Coklat  169000    Rendah
# 400         Full    Krem Hitam  169000    Tinggi
# 401         Full  Coklat Hitam  169000    Tinggi
# 402         Full   Putih Hitam  169000    Tinggi
#
# [403 rows x 9 columns]

# %% [markdown]
# # Split Data

# %%
from sklearn.model_selection import train_test_split

#split the data into train and test set
train,test = train_test_split(df, test_size=0.2, random_state=1)

#save the data
train.to_csv('train.csv',index=False)
test.to_csv('test.csv',index=False)

# %%
train
# Out:
#                  bahan warna_kemeja       tipe_kerah     tipe_lengan  \
# 185        Kain Flanel       Maroon  Straight Collar  Lengan Panjang
# 227       Katun Oxford          Abu  Straight Collar   Lengan Pendek
# 245              Katun          Abu  Shanghai Collar  Lengan Panjang
# 23        Katun Oxford          Abu  Straight Collar   Lengan Pendek
# 321  Katun Rayon Twill         Navy  Straight Collar   Lengan Pendek
# ..                 ...          ...              ...             ...
# 255       Katun Oxford          Abu  Shanghai Collar  Lengan Panjang
# 72        Katun Oxford          Abu  Straight Collar   Lengan Pendek
# 396              Katun        Hitam  Straight Collar  Lengan Panjang
# 235     Katun Yarndyed          Abu  Straight Collar   Lengan Pendek
# 37        Katun Oxford         Navy  Straight Collar   Lengan Pendek
#
#               motif     posisi_motif  warna_motif   harga penjualan
# 185  Square Pattern             Full        Hitam  169000    Rendah
# 227         Stripes  Dada Horizontal        Putih  129000    Rendah
# 245           Polos        Tidak Ada    Tidak Ada  149000    Rendah
# 23            Polos        Tidak Ada    Tidak Ada  129000    Tinggi
# 321          Flower             Full        Hijau  119000    Rendah
# ..              ...              ...          ...     ...       ...
# 255            Line  Dada Horizontal         Navy  149000    Rendah
# 72             Area    Dada Diagonal  Hitam Putih  129000    Rendah
# 396           Batik        Area Atas  Krem Coklat  169000    Rendah
# 235         Stripes  Dada Horizontal    Navy Biru  129000    Rendah
# 37           2 Line       Dada Kanan         Biru  129000    Rendah
#
# [322 rows x 9 columns]

# %%
test
# Out:
#             bahan warna_kemeja       tipe_kerah     tipe_lengan         motif  \
# 360         Katun         Navy  Straight Collar  Lengan Panjang         Batik
# 62   Katun Oxford        Putih  Straight Collar   Lengan Pendek        2 Line
# 374         Katun         Navy  Straight Collar   Lengan Pendek         Batik
# 92    Katun Linen         Navy  Shanghai Collar  Lengan Panjang  Koko Pattern
# 146   Katun Linen         Biru  Shanghai Collar  Lengan Panjang          Line
# ..            ...          ...              ...             ...           ...
# 11   Katun Oxford         Army  Straight Collar  Lengan Panjang         Polos
# 363         Katun        Putih  Straight Collar  Lengan Panjang         Batik
# 300  Katun Oxford        Putih  Shanghai Collar  Lengan Panjang         Polos
# 41   Katun Oxford         Navy  Straight Collar   Lengan Pendek        3 Line
# 161   Katun Pique  Coklat Muda  Straight Collar   Lengan Pendek         Polos
#
#          posisi_motif    warna_motif   harga penjualan
# 360              Full     Putih Navy  169000    Rendah
# 62   Dada Lengan Kiri       Navy Abu  129000    Rendah
# 374              Full   Coklat Putih  149000    Rendah
# 92    Dada Horizontal     Putih Biru  179000    Rendah
# 146   Dada Horizontal           Navy  179000    Tinggi
# ..                ...            ...     ...       ...
# 11          Tidak Ada      Tidak Ada  149000    Rendah
# 363              Full  Coklat Kuning  169000    Rendah
# 300         Tidak Ada      Tidak Ada  149000    Rendah
# 41    Dada Horizontal     Putih Biru  129000    Rendah
# 161         Tidak Ada      Tidak Ada  149000    Tinggi
#
# [81 rows x 9 columns]

# %% [markdown]
# # Encode Data

# %%
#encode category to numeric
df['bahan'] = pd.factorize(df['bahan'], sort=True)[0]
df['warna_kemeja'] = pd.factorize(df['warna_kemeja'], sort=True)[0]
df['tipe_kerah'] = pd.factorize(df['tipe_kerah'], sort=True)[0]
df['tipe_lengan'] = pd.factorize(df['tipe_lengan'], sort=True)[0]
df['motif'] = pd.factorize(df['motif'], sort=True)[0]
df['posisi_motif'] = pd.factorize(df['posisi_motif'], sort=True)[0]
df['warna_motif'] = pd.factorize(df['warna_motif'], sort=True)[0]
df['penjualan'] = pd.factorize(df['penjualan'], sort=True)[0]
df
# Out:
#      bahan  warna_kemeja  tipe_kerah  tipe_lengan  motif  posisi_motif  \
# 0        3            10           2            0     16            24
# 1        3             3           2            0     16            24
# 2        3             8           2            1     16            24
# 3        3             7           2            0     16            24
# 4        3            13           2            0     16            24
# ..     ...           ...         ...          ...    ...           ...
# 398      1             7           2            0      5             1
# 399      1            19           2            0      5             0
# 400      1             7           2            0      5             9
# 401      1            23           2            0      5             9
# 402      1             5           2            0      5             9
#
#      warna_motif   harga  penjualan
# 0             91  149000          0
# 1             91  149000          0
# 2             91  129000          0
# 3             91  149000          1
# 4             91  149000          0
# ..           ...     ...        ...
# 398           42  169000          0
# 399           42  169000          0
# 400           43  169000          1
# 401           19  169000          1
# 402           82  169000          1
#
# [403 rows x 9 columns]

# %%
#split the data into train and test set
train,test = train_test_split(df, test_size=0.2, random_state=1)

#save the data
train.to_csv('train_encode.csv',index=False)
test.to_csv('test_encode.csv',index=False)

# %%
train
# Out:
#      bahan  warna_kemeja  tipe_kerah  tipe_lengan  motif  posisi_motif  \
# 185      0            16           2            0     19             9
# 227      3             0           2            1     20             3
# 245      1             0           1            0     16            24
# 23       3             0           2            1     16            24
# 321      5            19           2            1      8             9
# ..     ...           ...         ...          ...    ...           ...
# 255      3             0           1            0     11             3
# 72       3             0           2            1      4             2
# 396      1            12           2            0      5             0
# 235      7             0           2            1     20             3
# 37       3            19           2            1      0             4
#
#      warna_motif   harga  penjualan
# 185           31  169000          0
# 227           76  129000          0
# 245           91  149000          0
# 23            91  129000          1
# 321           26  119000          0
# ..           ...     ...        ...
# 255           64  149000          0
# 72            39  129000          0
# 396           42  169000          0
# 235           66  129000          0
# 37             6  129000          0
#
# [322 rows x 9 columns]

# %%
test
# Out:
#      bahan  warna_kemeja  tipe_kerah  tipe_lengan  motif  posisi_motif  \
# 360      1            19           2            0      5             9
# 62       3            23           2            1      0             6
# 374      1            19           2            1      5             9
# 92       2            19           1            0      9             3
# 146      2             5           1            0     11             3
# ..     ...           ...         ...          ...    ...           ...
# 11       3             3           2            0     16            24
# 363      1            23           2            0      5             9
# 300      3            23           1            0     16            24
# 41       3            19           2            1      1             3
# 161      4             8           2            1     16            24
#
#      warna_motif   harga  penjualan
# 360           88  169000          0
# 62            65  129000          0
# 374           25  149000          0
# 92            78  179000          0
# 146           64  179000          1
# ..           ...     ...        ...
# 11            91  149000          0
# 363           21  169000          0
# 300           91  149000          0
# 41            78  129000          0
# 161           91  149000          1
#
# [81 rows x 9 columns]

# %%
df = pd.read_csv('train_encode.csv')

X_train= df.values
X_train = np.delete(X_train, 8, axis=1)

y_train = df['penjualan'].values

df = pd.read_csv('test_encode.csv')

X_test= df.values
X_test = np.delete(X_test, 8, axis=1)

y_test = df['penjualan'].values

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (322, 8)
# (322,)
# (81, 8)
# (81,)

# %%
from numpy import savetxt
savetxt('X_train_scale.csv', X_train, delimiter=',')
savetxt('X_test_scale.csv', X_test, delimiter=',')

# %% [markdown]
# # Apply Model

# %%
nb_clf = GaussianNB()

nb_clf.fit(X_train, y_train)
# Out:
# GaussianNB()

# %% [markdown]
# # Accuracy

# %%
y_pred = nb_clf.predict(X_test)

round(accuracy_score(y_test,y_pred),3)
# Out:
# 0.753
